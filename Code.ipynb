# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel("Product Quantities All.xlsx")

# %%
df.head()
# Out:
#         Date      Section       PE Work Center  Module  \
# 0 2018-01-02  PDC SECTION        ?      0252-A  0252-A
# 1 2018-01-02  PDC SECTION        ?      0253-A  0253-A
# 2 2018-01-02    SECTION 1  BANDARA      0013-A  0013-A
# 3 2018-01-02    SECTION 1  BANDARA      0041-A  0041-A
# 4 2018-01-02    SECTION 1  BANDARA      0043-A  0043-A
#
#    Planned/Projected Efficiency  Present Employees  Absent Employees  \
# 0                           0.0                9.0               1.0
# 1                           0.0                4.0               2.0
# 2                           0.0               19.0               0.0
# 3                           0.0               19.0               5.0
# 4                           0.0               17.0               2.0
#
#    No Of Hours Per Day  Worked Hours  ...                  Style Description  \
# 0                  9.0     65.250000  ...                      AMW0002- OPT1
# ...

# %% [markdown]
# ### Shape of Dataset

# %%
df.shape
# Out:
# (14460, 25)

# %%
df.isnull().sum()
# Out:
# Date                                0
# Section                             0
# PE                                  0
# Work Center                         0
# Module                              0
# Planned/Projected Efficiency      851
# Present Employees                 286
# Absent Employees                  286
# No Of Hours Per Day               286
# Worked Hours                        0
# Daily Down Time Hours             851
# Impacted DownTime Hours           851
# Daily Performance                 155
# Customer                          155
# Style Code                        155
# Style Description                 155
# SO                                155
# LI                                155
# FG Reference                      155
# SO/LI Worked Hours                  0
# Efficiency                          0
# Time Slot                       14460
# Total                               0
# SMV                                 0
# Standard Hours                      0
# ...

# %%
df = df.drop('Time Slot', axis=1)

# %%
df.isnull().sum()
# Out:
# Date                              0
# Section                           0
# PE                                0
# Work Center                       0
# Module                            0
# Planned/Projected Efficiency    851
# Present Employees               286
# Absent Employees                286
# No Of Hours Per Day             286
# Worked Hours                      0
# Daily Down Time Hours           851
# Impacted DownTime Hours         851
# Daily Performance               155
# Customer                        155
# Style Code                      155
# Style Description               155
# SO                              155
# LI                              155
# FG Reference                    155
# SO/LI Worked Hours                0
# Efficiency                        0
# Total                             0
# SMV                               0
# Standard Hours                    0
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# Date                            0
# Section                         0
# PE                              0
# Work Center                     0
# Module                          0
# Planned/Projected Efficiency    0
# Present Employees               0
# Absent Employees                0
# No Of Hours Per Day             0
# Worked Hours                    0
# Daily Down Time Hours           0
# Impacted DownTime Hours         0
# Daily Performance               0
# Customer                        0
# Style Code                      0
# Style Description               0
# SO                              0
# LI                              0
# FG Reference                    0
# SO/LI Worked Hours              0
# Efficiency                      0
# Total                           0
# SMV                             0
# Standard Hours                  0
# dtype: int64

# %%
df.shape
# Out:
# (13454, 24)

# %% [markdown]
# ### Statistical Information of Dataset

# %%
df.describe()
# Out:
#        Planned/Projected Efficiency  Present Employees  Absent Employees  \
# count                       13454.0       13454.000000      13454.000000
# mean                            0.0          11.777687          1.297384
# std                             0.0          10.822950          2.086638
# min                             0.0           0.000000          0.000000
# 25%                             0.0           0.000000          0.000000
# 50%                             0.0          13.000000          0.000000
# 75%                             0.0          21.000000          2.000000
# max                             0.0          49.000000         60.000000
#
#        No Of Hours Per Day  Worked Hours  Daily Down Time Hours  \
# count         13454.000000  13454.000000           13454.000000
# mean              6.255816    106.926794               0.132950
# std               4.628498    100.916963               2.329956
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13454 entries, 0 to 14459
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Date                          13454 non-null  datetime64[ns]
#  1   Section                       13454 non-null  object
#  2   PE                            13454 non-null  object
#  3   Work Center                   13454 non-null  object
#  4   Module                        13454 non-null  object
#  5   Planned/Projected Efficiency  13454 non-null  float64
#  6   Present Employees             13454 non-null  float64
#  7   Absent Employees              13454 non-null  float64
#  8   No Of Hours Per Day           13454 non-null  float64
#  9   Worked Hours                  13454 non-null  float64
#  10  Daily Down Time Hours         13454 non-null  float64
#  11  Impacted DownTime Hours       13454 non-null  float64
# ...

# %% [markdown]
# ### Outlier detection and Removal

# %%
sns.boxplot(x=df['SMV'])
# Out:
# <AxesSubplot:xlabel='SMV'>

# %%
df = df[df['SMV'] <= 25]

# %%
sns.boxplot(x=df['SMV'])
# Out:
# <AxesSubplot:xlabel='SMV'>

# %%
sns.boxplot(x=df['Planned/Projected Efficiency'])
# Out:
# <AxesSubplot:xlabel='Planned/Projected Efficiency'>

# %%
df = df[df['Planned/Projected Efficiency'] <= 0.02 ]

# %%
sns.boxplot(x=df['Planned/Projected Efficiency'])
# Out:
# <AxesSubplot:xlabel='Planned/Projected Efficiency'>

# %%
sns.boxplot(x=df['Present Employees'])
# Out:
# <AxesSubplot:xlabel='Present Employees'>

# %%
sns.boxplot(x=df['Absent Employees'])
# Out:
# <AxesSubplot:xlabel='Absent Employees'>

# %%
df = df[df['Absent Employees'] <= 15]

# %%
sns.boxplot(x=df['Absent Employees'])
# Out:
# <AxesSubplot:xlabel='Absent Employees'>

# %%
sns.boxplot(x=df['No Of Hours Per Day'])
# Out:
# <AxesSubplot:xlabel='No Of Hours Per Day'>

# %%
sns.boxplot(x=df['Worked Hours'])
# Out:
# <AxesSubplot:xlabel='Worked Hours'>

# %%
sns.boxplot(x=df['Daily Down Time Hours'])
# Out:
# <AxesSubplot:xlabel='Daily Down Time Hours'>

# %%
df = df[df['Daily Down Time Hours'] <= 5]

# %%
sns.boxplot(x=df['Daily Down Time Hours'])
# Out:
# <AxesSubplot:xlabel='Daily Down Time Hours'>

# %%
sns.boxplot(x=df['Impacted DownTime Hours'])
# Out:
# <AxesSubplot:xlabel='Impacted DownTime Hours'>

# %%
df = df[df['Impacted DownTime Hours'] <= 3]

# %%
sns.boxplot(x=df['Impacted DownTime Hours'])
# Out:
# <AxesSubplot:xlabel='Impacted DownTime Hours'>

# %%
sns.boxplot(x=df['Daily Performance'])
# Out:
# <AxesSubplot:xlabel='Daily Performance'>

# %%
df = df[df['Daily Performance'] <= 100]

# %%
sns.boxplot(x=df['Daily Performance'])
# Out:
# <AxesSubplot:xlabel='Daily Performance'>

# %%
sns.boxplot(x=df['LI'])
# Out:
# <AxesSubplot:xlabel='LI'>

# %%
df = df[df['LI'] <= 150]

# %%
sns.boxplot(x=df['LI'])
# Out:
# <AxesSubplot:xlabel='LI'>

# %%
sns.boxplot(x=df['SO/LI Worked Hours'])
# Out:
# <AxesSubplot:xlabel='SO/LI Worked Hours'>

# %%
df = df[df['SO/LI Worked Hours'] <= 400]

# %%
sns.boxplot(x=df['SO/LI Worked Hours'])
# Out:
# <AxesSubplot:xlabel='SO/LI Worked Hours'>

# %%
sns.boxplot(x=df['Efficiency'])
# Out:
# <AxesSubplot:xlabel='Efficiency'>

# %%
df = df[df['Efficiency'] <= 100]

# %%
sns.boxplot(x=df['Efficiency'])
# Out:
# <AxesSubplot:xlabel='Efficiency'>

# %%
sns.boxplot(x=df['Total'])
# Out:
# <AxesSubplot:xlabel='Total'>

# %%
df = df[df['Total'] <= 400]

# %%
sns.boxplot(x=df['Total'])
# Out:
# <AxesSubplot:xlabel='Total'>

# %%
sns.boxplot(x=df['Standard Hours'])
# Out:
# <AxesSubplot:xlabel='Standard Hours'>

# %%
df = df[df['Standard Hours'] <= 30]

# %%
sns.boxplot(x=df['Standard Hours'])
# Out:
# <AxesSubplot:xlabel='Standard Hours'>

# %% [markdown]
# ### Shape of Dataset after removing outlier

# %%
df.shape
# Out:
# (7891, 24)

# %%
df.describe()
# Out:
#        Planned/Projected Efficiency  Present Employees  Absent Employees  \
# count                        7891.0        7891.000000       7891.000000
# mean                            0.0          11.207832          1.276137
# std                             0.0          10.530378          1.900947
# min                             0.0           0.000000          0.000000
# 25%                             0.0           0.000000          0.000000
# 50%                             0.0          12.000000          0.000000
# 75%                             0.0          20.000000          2.000000
# max                             0.0          43.000000         15.000000
#
#        No Of Hours Per Day  Worked Hours  Daily Down Time Hours  \
# count          7891.000000   7891.000000            7891.000000
# mean              6.183310    102.169594               0.000517
# std               4.677762     98.418387               0.026598
# ...

# %% [markdown]
# ### Analysis

# %%
columns = ["SMV","Work Center","Present Employees","Absent Employees","No Of Hours Per Day","Worked Hours","Daily Down Time Hours","Impacted DownTime Hours","Daily Performance","LI","SO/LI Worked Hours","Efficiency","Total","Standard Hours"]

for column in columns:
    sns.histplot(x=df[column])
    plt.title(f"distribution of {column}")
    plt.xlim(df[column].min(), df[column].max())
    plt.show()

# %%
df.groupby(['Work Center'])['Present Employees'].sum().plot(kind='line',rot=90)
# Out:
# <AxesSubplot:xlabel='Work Center'>

# %%
df.groupby(['Work Center'])['Absent Employees'].sum().plot(kind='line',rot=90)
# Out:
# <AxesSubplot:xlabel='Work Center'>

# %%
df.groupby(['Work Center'])['No Of Hours Per Day'].sum().plot(kind='line',rot=90)
# Out:
# <AxesSubplot:xlabel='Work Center'>

# %%
df.groupby(['Work Center'])['Worked Hours'].sum().plot(kind='line',rot=90)
# Out:
# <AxesSubplot:xlabel='Work Center'>

# %%
df.groupby(['Work Center'])['Daily Down Time Hours'].sum().plot(kind='line',rot=90)
# Out:
# <AxesSubplot:xlabel='Work Center'>

# %%
df.groupby(['Work Center'])['Daily Performance'].sum().plot(kind='line',rot=90)
# Out:
# <AxesSubplot:xlabel='Work Center'>

# %%
df.groupby(['Work Center'])['Efficiency'].sum().plot(kind='line',rot=90)
# Out:
# <AxesSubplot:xlabel='Work Center'>

# %%
df.groupby(['Work Center'])['Total'].sum().plot(kind='line',rot=90)
# Out:
# <AxesSubplot:xlabel='Work Center'>

# %%
df.groupby(['Work Center'])['Standard Hours'].sum().plot(kind='line',rot=90)
# Out:
# <AxesSubplot:xlabel='Work Center'>

# %%
df.groupby(['Module'])['Efficiency'].sum().plot(kind='line',rot=90)
# Out:
# <AxesSubplot:xlabel='Module'>

# %%
df.plot(x='Standard Hours', y='Efficiency', style='o')
# Out:
# <AxesSubplot:xlabel='Standard Hours'>

# %%
df.plot(x='Worked Hours', y='Efficiency', style='o')
# Out:
# <AxesSubplot:xlabel='Worked Hours'>

# %%
df.groupby(['Date'])['Efficiency'].sum().plot(kind='line',rot=90)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
corr_matrix = df.corr()

# Create a larger figure with Matplotlib
fig, ax = plt.subplots(figsize=(15,15))

# Plot the correlation matrix using Seaborn's heatmap function
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', ax=ax)

# Display the plot
plt.show()

# %% [markdown]
# ### Label Encoding

# %%
df.columns
# Out:
# Index(['Date', 'Section', 'PE', 'Work Center', 'Module',
#        'Planned/Projected Efficiency', 'Present Employees', 'Absent Employees',
#        'No Of Hours Per Day', 'Worked Hours', 'Daily Down Time Hours',
#        'Impacted DownTime Hours', 'Daily Performance', 'Customer',
#        'Style Code', 'Style Description', 'SO', 'LI', 'FG Reference',
#        'SO/LI Worked Hours', 'Efficiency', 'Total', 'SMV', 'Standard Hours'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8434 entries, 0 to 14459
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Date                          8434 non-null   datetime64[ns]
#  1   Section                       8434 non-null   object
#  2   PE                            8434 non-null   object
#  3   Work Center                   8434 non-null   object
#  4   Module                        8434 non-null   object
#  5   Planned/Projected Efficiency  8434 non-null   float64
#  6   Present Employees             8434 non-null   float64
#  7   Absent Employees              8434 non-null   float64
#  8   No Of Hours Per Day           8434 non-null   float64
#  9   Worked Hours                  8434 non-null   float64
#  10  Daily Down Time Hours         8434 non-null   float64
#  11  Impacted DownTime Hours       8434 non-null   float64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
# Create a label encoder object
le = LabelEncoder()

# Fit the encoder to the column data
le.fit(df['Section'])

# Transform the column using the fitted encoder
df['Section'] = le.transform(df['Section'])


# Fit the encoder to the column data
le.fit(df['PE'])

# Transform the column using the fitted encoder
df['PE'] = le.transform(df['PE'])


# Fit the encoder to the column data
le.fit(df['Customer'])

# Transform the column using the fitted encoder
df['Customer'] = le.transform(df['Customer'])

# Fit the encoder to the column data
le.fit(df['Work Center'])

# Transform the column using the fitted encoder
df['Work Center'] = le.transform(df['Work Center'])

# %%
df.head()
# Out:
#         Date  Section  PE  Work Center  Module  Planned/Projected Efficiency  \
# 0 2018-01-02        0   0          118  0252-A                           0.0
# 2 2018-01-02        1   1           11  0013-A                           0.0
# 3 2018-01-02        1   1           34  0041-A                           0.0
# 4 2018-01-02        1   1           36  0043-A                           0.0
# 5 2018-01-02        1   1           39  0047-A                           0.0
#
#    Present Employees  Absent Employees  No Of Hours Per Day  Worked Hours  \
# 0                9.0               1.0                  9.0     65.250000
# 2               19.0               0.0                  9.0    128.983333
# 3               19.0               5.0                  9.0    137.666667
# 4               17.0               2.0                  9.0    120.133333
# 5               16.0               1.0                  9.0    108.750000
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8434 entries, 0 to 14459
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Date                          8434 non-null   datetime64[ns]
#  1   Section                       8434 non-null   int64
#  2   PE                            8434 non-null   int64
#  3   Work Center                   8434 non-null   int32
#  4   Module                        8434 non-null   object
#  5   Planned/Projected Efficiency  8434 non-null   float64
#  6   Present Employees             8434 non-null   float64
#  7   Absent Employees              8434 non-null   float64
#  8   No Of Hours Per Day           8434 non-null   float64
#  9   Worked Hours                  8434 non-null   float64
#  10  Daily Down Time Hours         8434 non-null   float64
#  11  Impacted DownTime Hours       8434 non-null   float64
# ...

# %% [markdown]
# ### Separating the Target Variable

# %%
X, y = df.drop(columns=["Date","Module","Style Code","Style Description","SO","FG Reference","SO/LI Worked Hours","Worked Hours"]), df["Worked Hours"]

# %%
X
# Out:
#        Section  PE  Work Center  Planned/Projected Efficiency  \
# 0            0   0          118                           0.0
# 2            1   1           11                           0.0
# 3            1   1           34                           0.0
# 4            1   1           36                           0.0
# 5            1   1           39                           0.0
# ...        ...  ..          ...                           ...
# 14455        4  10           41                           0.0
# 14456        4  10           41                           0.0
# 14457        4  10           41                           0.0
# 14458        4  10           95                           0.0
# 14459        4  11           73                           0.0
#
#        Present Employees  Absent Employees  No Of Hours Per Day  \
# 0                    9.0               1.0                  9.0
# 2                   19.0               0.0                  9.0
# ...

# %%
y
# Out:
# 0         65.250000
# 2        128.983333
# 3        137.666667
# 4        120.133333
# 5        108.750000
#             ...
# 14455    126.000000
# 14456      0.000000
# 14457      0.000000
# 14458     90.000000
# 14459     99.000000
# Name: Worked Hours, Length: 8434, dtype: float64

# %% [markdown]
# ### Splitting into training and testing dataset

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# ### Modeling Data

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet, BayesianRidge
from sklearn.metrics import r2_score


# Define five linear regression algorithms
models = [LinearRegression(), Ridge(), Lasso(), ElasticNet(), BayesianRidge()]

# Train each algorithm on the training set and predict the values for the testing set
accuracies = []
for model in models:
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracy = r2_score(y_test, y_pred)
    accuracies.append(accuracy)
    print(f'{model.__class__.__name__} Accuracy: {accuracy:.4f}')

# Store the accuracies in a data frame
metrics = pd.DataFrame(accuracies, columns=['Accuracy'], index=['Linear Regression', 'Ridge', 'Lasso', 'Elastic Net', 'Bayesian Ridge'])

# Visualize the accuracies on a bar graph
fig, ax = plt.subplots(figsize=(10,6))
metrics.plot(kind='bar', ax=ax)
plt.xlabel('Algorithm')
plt.ylabel('Accuracy')
plt.title('Accuracy of Linear Regression Algorithms')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# LinearRegression Accuracy: 0.9620
# Ridge Accuracy: 0.9620
# Lasso Accuracy: 0.9617
# ElasticNet Accuracy: 0.9616
# BayesianRidge Accuracy: 0.9620
